# %% [raw]
# ---
# title: "About"
# ---
#
# # Header 1
# School: Georgetown University
#
# ## Header 2
# Department: DSAN
#
# ### Header 3
# Author: Yinhong Chen

# %%
# importing the required module
import matplotlib.pyplot as plt
  
x = [1,2,3]
y = [4,5,6]

plt.plot(x, y)

plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Plot')
plt.show()

# %% [markdown]
# About this site
